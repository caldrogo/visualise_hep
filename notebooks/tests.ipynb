# %%
import json
import pandas as pd

# %%
records = []
with open("../data/raw_metadata.jsonl", encoding="utf-8") as f:
    for line in f:
        records.append(json.loads(line))

# %%
df = pd.DataFrame(records)

# %%
df[df['id'].str.contains('2606.20220')]
# Out:
#                  id                                              title  \
# 69067  2606.20220v3  Higher-loop wormhole length in sine-dilaton gr...
#
#                                                 abstract categories  \
# 69067  The quantum wormhole length in sine-dilaton gr...   [hep-th]
#
#       primary_category             published               updated  \
# 69067           hep-th  2026-06-18T13:35:38Z  2026-06-29T07:29:04Z
#
#                                     authors
# 69067  [Eleonora Alfinito, Matteo Beccaria]

# %%
df[df['id'].str.contains('v3')].tail(5)
# Out:
#                  id                                              title  \
# 68986  2606.18639v3  A Note on Corrections to Entanglement Wedge Re...
# 69067  2606.20220v3  Higher-loop wormhole length in sine-dilaton gr...
# 69115  2606.21079v3  Linear Growth of Holographic Time-like Entangl...
# 69175  2606.22531v3        Steering a warp drive without exotic matter
# 69247  2606.24008v3  General Lagrangian formulations for mixed-anti...
#
#                                                 abstract  \
# 68986  If entanglement wedge reconstruction is exact,...
# 69067  The quantum wormhole length in sine-dilaton gr...
# 69115  The holographic time-like entanglement entropy...
# 69175  A useful warp drive must accelerate, yet every...
# 69247  Lagrangian formulations for (ir)reducible inte...
#
#                                 categories primary_category  \
# 68986                             [hep-th]           hep-th
# 69067                             [hep-th]           hep-th
# ...
